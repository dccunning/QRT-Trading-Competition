# %% [markdown]
# ## VectorBT

# %%
import vectorbt as vbt

# Download data for Bitcoin
price = vbt.YFData.download('BTC-USD').get('Close')

fast_ma = vbt.MA.run(price, 10)
slow_ma = vbt.MA.run(price, 50)

# Generate signals: True when fast crosses above slow
entries = fast_ma.ma_crossed_above(slow_ma)
exits = fast_ma.ma_crossed_below(slow_ma)

portfolio = vbt.Portfolio.from_signals(price, entries, exits, init_cash=10_000)

portfolio.stats()
# Out:
# /Users/dcunning/Code/Python/imperial/.venv/lib/python3.12/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'sharpe_ratio' requires frequency to be set
#
# /Users/dcunning/Code/Python/imperial/.venv/lib/python3.12/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'calmar_ratio' requires frequency to be set
#
# /Users/dcunning/Code/Python/imperial/.venv/lib/python3.12/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'omega_ratio' requires frequency to be set
#
# /Users/dcunning/Code/Python/imperial/.venv/lib/python3.12/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'sortino_ratio' requires frequency to be set
# Start                         2014-09-17 00:00:00+00:00
# End                           2026-01-26 00:00:00+00:00
# Period                                             4149
# Start Value                                     10000.0
# End Value                                3182811.313578
# Total Return [%]                           31728.113136
# Benchmark Return [%]                       18828.624647
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                                     0.0
# Max Drawdown [%]                              72.193683
# Max Drawdown Duration                            1053.0
# Total Trades                                         49
# Total Closed Trades                                  48
# Total Open Trades                                     1
# Open Trade PnL                           -268969.646508
# Win Rate [%]                                       50.0
# Best Trade [%]                               333.139712
# Worst Trade [%]                              -19.973111
# Avg Winning Trade [%]                         51.327727
# Avg Losing Trade [%]                          -8.767792
# Avg Winning Trade Duration                    79.166667
# Avg Losing Trade Duration                     16.416667
# Profit Factor                                  2.275442
# Expectancy                                 71703.770002
# dtype: object

# %%
portfolio.plot_position_pnl()
# Out:
# FigureWidget({
#     'data': [{'customdata': {'bdata': ('AAAAAAAAAECAeJrMplFyQFuZg3GRTa' ... 'AAAACARkA4xAv4EJwVQbIw9gBub7c/'),
#                              'dtype': 'f8',
#                              'shape': '24, 3'},
#               'hovertemplate': ('Position Id: %{customdata[0]}<' ... 'r>Return: %{customdata[2]:.2%}'),
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'opacity': {'bdata': ('qb3zSeUL6D8rU5L+uRjoP1SPM1JK4O' ... 'AwNZOt6D8voLht70PoPzV5fOY0Ieg/'),
#                                      'dtype': 'f8'},
#                          'size': {'bdata': ('rCdjL2RFHEAk5ar3PJAcQF63axouji' ... 'DxYIX0H0ASUQoASowdQF8Y1pW0wRxA'),
#                                   'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Profit',
#               'type': 'scatter',
#               'uid': '20764de4-d7a0-49fd-82d8-d69e84c046b3',
#               'x': array([Timestamp('2015-03-28 00:00:00+0000', tz='UTC'),
#                           Timestamp('2015-08-12 00:00:00+0000', tz='UTC'),
#                           Timestamp('2016-01-17 00:00:00+0000', tz='UTC'),
#                           Timestamp('2016-07-26 00:00:00+0000', tz='UTC'),
#                           Timestamp('2017-01-17 00:00:00+0000', tz='UTC'),
#                           Timestamp('2017-03-23 00:00:00+0000', tz='UTC'),
#                           Timestamp('2017-07-10 00:00:00+0000', tz='UTC'),
#                           Timestamp('2017-09-17 00:00:00+0000', tz='UTC'),
#                           Timestamp('2018-01-16 00:00:00+0000', tz='UTC'),
#                           Timestamp('2019-07-25 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-03-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-24 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-09-06 00:00:00+0000', tz='UTC'),
#                           Timestamp('2021-04-24 00:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-20 00:00:00+0000', tz='UTC'),
#                           Timestamp('2021-11-23 00:00:00+0000', tz='UTC'),
#                           Timestamp('2022-08-24 00:00:00+0000', tz='UTC'),
#                           Timestamp('2023-03-07 00:00:00+0000', tz='UTC'),
#                           Timestamp('2023-05-10 00:00:00+0000', tz='UTC'),
#                           Timestamp('2024-01-20 00:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-17 00:00:00+0000', tz='UTC'),
#                           Timestamp('2024-12-30 00:00:00+0000', tz='UTC'),
#                           Timestamp('2025-06-22 00:00:00+0000', tz='UTC'),
#                           Timestamp('2025-08-23 00:00:00+0000', tz='UTC')], dtype=object),
#               'y': {'bdata': ('W5mDcZFNoT8nJ6bwb42xP3QVUnbHf+' ... 'lv1+gz3j/aCDZcd8PHP7Iw9gBub7c/'),
#                     'dtype': 'f8'}},
#              {'customdata': {'bdata': ('AAAAAAAAAAAAuT9A5ImBwJayMAg9vK' ... 'AAAACAR0Doy6xqRUMfwWYwXfIiisC/'),
#                              'dtype': 'f8',
#                              'shape': '24, 3'},
#               'hovertemplate': ('Position Id: %{customdata[0]}<' ... 'r>Return: %{customdata[2]:.2%}'),
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': {'bdata': ('200rtCIU6D8Bjx4WXR3oP7er3GI9GO' ... '/prC0Q6D8Ktg6+8RXoPw3PZsQbL+g/'),
#                                      'dtype': 'f8'},
#                          'size': {'bdata': ('fZv8GnV1HEAvQrKrSascQP8+BxZmjR' ... 'b7xV9eHEA4ewAqAoAcQM63V6TMEh1A'),
#                                   'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': '1db34e7d-aa52-44d9-bb21-343c7650df3c',
#               'x': array([Timestamp('2014-11-29 00:00:00+0000', tz='UTC'),
#                           Timestamp('2014-12-13 00:00:00+0000', tz='UTC'),
#                           Timestamp('2015-06-03 00:00:00+0000', tz='UTC'),
#                           Timestamp('2016-04-06 00:00:00+0000', tz='UTC'),
#                           Timestamp('2018-03-13 00:00:00+0000', tz='UTC'),
#                           Timestamp('2018-05-22 00:00:00+0000', tz='UTC'),
#                           Timestamp('2018-08-11 00:00:00+0000', tz='UTC'),
#                           Timestamp('2018-09-07 00:00:00+0000', tz='UTC'),
#                           Timestamp('2018-10-02 00:00:00+0000', tz='UTC'),
#                           Timestamp('2018-10-25 00:00:00+0000', tz='UTC'),
#                           Timestamp('2019-01-16 00:00:00+0000', tz='UTC'),
#                           Timestamp('2019-08-19 00:00:00+0000', tz='UTC'),
#                           Timestamp('2019-11-20 00:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-11 00:00:00+0000', tz='UTC'),
#                           Timestamp('2022-02-22 00:00:00+0000', tz='UTC'),
#                           Timestamp('2022-03-12 00:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-14 00:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-11 00:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-31 00:00:00+0000', tz='UTC'),
#                           Timestamp('2024-06-20 00:00:00+0000', tz='UTC'),
#                           Timestamp('2024-08-06 00:00:00+0000', tz='UTC'),
#                           Timestamp('2025-02-09 00:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 00:00:00+0000', tz='UTC'),
#                           Timestamp('2025-10-17 00:00:00+0000', tz='UTC')], dtype=object),
#               'y': {'bdata': ('lrIwCD28rL8nM2su8cS0vzf+35j+Nr' ... 'DE7ro+p7/jOhdSrD6vv2YwXfIiisC/'),
#                     'dtype': 'f8'}},
#              {'customdata': {'bdata': 'AAAAAAAASEBgQQaWpmoQwZ5j+hSy8rO/', 'dtype': 'f8', 'shape': '1, 3'},
#               'hovertemplate': ('Position Id: %{customdata[0]}<' ... 'r>Return: %{customdata[2]:.2%}'),
#               'marker': {'color': '#FFAA00',
#                          'line': {'color': 'rgb(178,118,0)', 'width': 1},
#                          'opacity': {'bdata': 'Sxl8Ay4c6D8=', 'dtype': 'f8'},
#                          'size': {'bdata': 'iZP+vmGkHEA=', 'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Open',
#               'type': 'scatter',
#               'uid': '25ca3d51-7776-4dfd-8e63-c119741ef388',
#               'x': array([Timestamp('2026-01-26 00:00:00+0000', tz='UTC')], dtype=object),
#               'y': {'bdata': 'nmP6FLLys78=', 'dtype': 'f8'}}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y'}],
#                'template': '...',
#                'width': 700,
#                'yaxis': {'tickformat': '.2%'}}
# })
